# %%
import main

# %%
class Config(object):
    cell_size = 512
    num_layers = 1
    batch_size = 32
    input_size = 128
    learning_rate = 0.01
    cell_type = "gru"
    encoder_end_padding = False
    decoder_go_padding = True #This has to be always true.
    is_training = True
    seed = 10
    output_projection = None
    number_epochs = 1000
    lr_decay = 0.5
    decay_epoch = 20
    keep_prob = 0.5
    #Dataset-parameters
    #Assuming that the lower limit is always '1'. 
    #<go> & <end> padding have index '0'.
    upper_limit = 10
    source_vocab_size = upper_limit + 2#Change to upper_limit+1 if end_padding = True.
    target_vocab_size = upper_limit + 2
    lenght = 5
    training_example_count = 10000
    test_example_count = 1000
    encoder_time_steps = lenght
    decoder_time_steps = lenght
    number_repetition = True
    one_hot_repr = True
    attention_mechanism = False

# %%
main.train(Config)
# Out:
# Epoch number 1, Loss : 241764.0 test loss : 24165.7
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 1 1 1]
# Epoch number 2, Loss : 212047.0 test loss : 21188.8
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 1 1 1]
# Epoch number 3, Loss : 203123.0 test loss : 20293.3
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 1 1 1]
# Epoch number 4, Loss : 200098.0 test loss : 19988.6
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 1 1 1]
# Epoch number 5, Loss : 199076.0 test loss : 19882.9
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 1 1 1]
# Epoch number 6, Loss : 198307.0 test loss : 19806.9
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 0 0 0]
# Epoch number 7, Loss : 196225.0 test loss : 19602.5
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 0 0 0]
# Epoch number 8, Loss : 193092.0 test loss : 19287.0
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 0 0 0]
# Epoch number 9, Loss : 188365.0 test loss : 18805.9
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 1 0 0 0]
# Epoch number 10, Loss : 184440.0 test loss : 18409.4
# [7 4 5 2 2] [0 2 2 4 5 7] [1 1 0 0 0 0]
# ...
